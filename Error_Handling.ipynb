# %% [markdown]
# # Welcome to error handling!
# * Here we will explain what errors to expect and how to fix them. Luckily there are not many errors that you will likely run into unless you really love to mess with the code.

# %% [markdown]
# # Where to find Megadector
# * MegaDetector is located in the "C:\Users\Public\Documents\MegaDetector" file path.
#  ![image.png](attachment:ba830766-d3dd-4dfe-a59b-8c7f160bbac5.png)
# * This is important since many file paths are located within the megadetector folder.

# %% [markdown]
# # Pathing errors
# * These will be the most common errors that you will receive. Thankfully these are easy to solve.
# * Take for example copying a path in windows and pasting it in here for a command, we'll use the single image processing as an example.

# %%
import os # this import statement allows us to use the file pathing system in windows

# %%
image_path = os.path.abspath("C:\Users\Public\Documents\MegaDetector\images\channel-islands-thumb.jpg")
# Out:
#   Cell In[5], line 1
#     image_path = os.path.abspath("C:\Users\Public\Documents\MegaDetector\images\channel-islands-thumb.jpg")
#                                                                                                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# * Error, this is a direct copy from an images in our images folder. You can select any image from any folder but you will receive the same error unless you change the backwards slashes to forward slashes like below

# %%
image_path = os.path.abspath("C:/Users/Public/Documents/MegaDetector/images/orinoquia-thumb-web.jpg")

# %% [markdown]
# * Now lets test it out with our command to annotate the image.

# %%
# !python "C:\Users\Public\Documents\MegaDetector\megadetector\detection\run_detector.py" MDV5A --image_file "{image_path}" --threshold 0.1
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Public\Documents\MegaDetector\megadetector\detection\run_detector.py", line 761, in <module>
#     main()
#   File "C:\Users\Public\Documents\MegaDetector\megadetector\detection\run_detector.py", line 720, in main
#     assert os.path.exists(args.detector_file), 'detector file {} does not exist'.format(
# AssertionError: detector file MDV5 does not exist

# %% [markdown]
# * You may have noticed that the command to annotate has backwards slashes, that's because we are not using the os for that path and the program is fine with it.
# * remember to be careful with this as it will be 90% of your problems.

# %% [markdown]
# # MegaDetector Model
# # Current model / models: MDV5A
# * We have the option to select what MegaDetector models we want to use. This is only important for two steps of the MegaDetector process.
# * As you can see what we did above, !python "C:\Users\Public\Documents\MegaDetector\megadetector\detection\run_detector.py" MDV5A --image_file "{image_path}" --threshold 0.1,
# * we selected "MDV5A" or MegaDetector Version 5A. More versions may be added that are more specialized for classification. When you want to use those models, you will need to change the name there.
# * If the model does not exist, then you will get this error
# ![image.png](attachment:dbd5b2cf-c13d-4133-850f-6862fc36e8aa.png)
# * It is stating that the MD file does not exist because it does not. The only way to fix this is to replace it with one that does exist.

# %% [markdown]
# # Deleted cells and are freaking out?
# * Go to the "code_depot" if you are fully unable to recover anything that you deleted. There will be all the cells you will need for any part of the notebooks.
